# %%
#!pip install --quiet https://github.com/kpu/kenlm/archive/master.zip > /dev/null
#!pip install --quiet nltk --upgrade > /dev/null
#!pip install --quiet pyarrow --upgrade > /dev/null
#!git clone --quiet https://github.com/williamSYSU/TextGAN-PyTorch.git > /dev/null
# !find ./TextGAN-PyTorch/run/ -type f -exec sed -r -i "s/(rootdir = )(.*)/\1'.\/TextGAN-PyTorch\/'/g; s/(executable = )(.*)/\1'python'/g ; s/(if_real_data = )(.*)/\1(1,)/g ; s/(dataset = )(.*)/\1('lyrics',)/g ; s/(vocab_size = )(.*)/\1(0,)/g ; s/(batch_size = )(.*)/\18/g" {} \;
#!nvidia-smi

# %%
import os
import nltk
import pandas as pd
import numpy as np
nltk.download('punkt')
os.makedirs('./TextGAN-PyTorch/dataset/testdata', exist_ok=True)
data = pd.read_feather('https://github.com/Scytheface/NARV/raw/main/lyrics/lyrics.ft')
mask = np.random.rand(len(data)) < 0.8
with open('./TextGAN-PyTorch/dataset/lyrics.txt', 'w') as trainfile, open('./TextGAN-PyTorch/dataset/testdata/lyrics_test.txt', 'w') as testfile:
  trainfile.write('\n'.join(map(lambda x: x.replace('\n', '|'), data[mask]['lyrics'])).lower())
  testfile.write('\n'.join(map(lambda x: x.replace('\n', '|'), data[~mask]['lyrics'])).lower())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
models = ['cot', 'dgsan', 'dpgan', 'jsdgan', 'leakgan', 'maligan', 'relgan', 'seqgan']

model = f"run_{models[2]}.py"
# !python ./TextGAN-PyTorch/run/$model 0 0
# Out:
# job_id: 0, gpu_id: 0
# ...
# > training arguments:
# >>> if_test: 0
# >>> run_model: dpgan
# >>> k_label: 2
# >>> dataset: lyrics
# >>> model_type: vanilla
# >>> loss_type: rsgan
# >>> mu_type: ragan
# >>> eval_type: Ra
# >>> d_type: Ra
# >>> if_real_data: 1
# >>> cuda: 1
# >>> device: 0
# >>> devices: 0
# >>> shuffle: 0
# >>> gen_init: normal
# >>> dis_init: uniform
# >>> n_parent: 1
# >>> eval_b_num: 8
# >>> lambda_fq: 1.0
# >>> lambda_fd: 0.0
# >>> d_out_mean: True
# >>> freeze_dis: False
# >>> freeze_clas: False
# >>> use_all_real_fake: False
# >>> use_population: False
# >>> samples_num: 10000
# >>> vocab_size: 42992
# >>> mle_epoch: 120
# >>> clas_pre_epoch: 10
# >>> adv_epoch: 200
# >>> inter_epoch: 15
# >>> batch_size: 8
# >>> max_seq_len: 1101
# >>> start_letter: 1
# >>> padding_idx: 0
# >>> gen_lr: 0.01
# >>> gen_adv_lr: 0.0001
# >>> dis_lr: 0.01
# >>> clip_norm: 5.0
# >>> pre_log_step: 10
# >>> adv_log_step: 1
# >>> train_data: dataset/lyrics.txt
# ...

# %%
# !nvidia-smi
# Out:
# Fri Jan  1 19:11:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    47W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...
